# %%
import seaborn as sns #this is the plotting library I'll be using 
import pandas as pd #"as pd" means that we can use the abbreviation in commands
import matplotlib.pyplot as plt #we need Matplotlib for setting the labels in the Seaborn graphs
# %matplotlib inline

df_srv = pd.read_csv('survey.csv', sep=',')
df_srv.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
df_stp = pd.read_csv('steps.csv', sep=';')
df_stp.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    3914.0    4364.0       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    7-5-2014  8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %%
df_mrg = pd.merge(df_srv,df_stp , on = 'id')
df_mrg.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  7-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    3914.0    4364.0       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %%
df_mrg.info() #Get information on the variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Columns: 337 entries, id to 13-5-2014
# dtypes: float64(330), int64(3), object(4)
# memory usage: 2.4+ MB

# %%
sns.distplot(df_mrg["height"], kde=False) #kde=False means we don't get an overlying density plot
plt.title("Height distribution of participants")
plt.xlabel("Height")
plt.ylabel("Count")
plt.show()

# %%
sns.set_style('whitegrid') 
sns.kdeplot(df_mrg['height'])

# %%
sns.distplot(df_mrg["weight"], kde=False)
plt.title("Weight distribution of participants")
plt.xlabel("Weight")
plt.ylabel("Count")
plt.show()

# %%
sns.set_style('whitegrid') 
sns.kdeplot(df_mrg['weight'])

# %%
# calculate values statistics for height
mean = str(float(df_mrg[['height']].mean()))
median = str(float(df_mrg[['height']].median()))
mode = str(df_mrg[['height']].mode()['height'][0])
variance = str(float(df_mrg[['height']].var()))
stdev = str(float(df_mrg[['height']].std()))

# %%
print('median: ', median)
print('mode: ' , mode)
print('mean: ' , mean)
print('standard deviation: ', stdev)
print('variance: ', variance)
# Out:
# median:  172.0
# mode:  170.0
# mean:  171.66810344827587
# standard deviation:  9.080235412579503
# variance:  82.45067514786287

# %%
# calculate values for weight
mean = str(float(df_mrg[['weight']].mean()))
median = str(float(df_mrg[['weight']].median()))
mode = str(df_mrg[['weight']].mode()['weight'][0])
variance = str(float(df_mrg[['weight']].var()))
stdev = str(float(df_mrg[['weight']].std()))

# %%
print('median: ', median)
print('mode: ' , mode)
print('mean: ' , mean)
print('standard deviation: ', stdev)
print('variance: ', variance)
# Out:
# median:  71.0
# mode:  72.0
# mean:  72.83387270765911
# standard deviation:  25.902717495406677
# variance:  670.9507736468471

# %%
mean_steps = df_mrg.loc[:,"20-6-2013":"13-5-2014"].mean() #get the mean over the columns (all the dates) and store
mean_steps.index #the indexes now contain the dates
# Out:
# Index(['20-6-2013', '21-6-2013', '22-6-2013', '23-6-2013', '24-6-2013',
#        '25-6-2013', '26-6-2013', '27-6-2013', '28-6-2013', '29-6-2013',
#        ...
#        '4-5-2014', '5-5-2014', '6-5-2014', '7-5-2014', '8-5-2014', '9-5-2014',
#        '10-5-2014', '11-5-2014', '12-5-2014', '13-5-2014'],
#       dtype='object', length=328)

# %%
plt.figure(figsize=(25, 6)) #set the figure ("canvas") size
plot = sns.lineplot(x=mean_steps.index, y=mean_steps) #create the plot

for ind, label in enumerate(plot.get_xticklabels()):
    if ind % 20 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)

plt.title("Mean steps per date")
plt.xlabel("Date")
plt.ylabel("steps")

plt.show()
